# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings. filterwarnings("ignore")

# %%
data=pd.read_csv("Automobile_data.csv")

# %%
data
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
# We need to check the unique data of all columns so as to make sure is there any characters or blank value in the data.

for col in data:
    print(col,":",data[col].unique())
    print("******************************************")
# Out:
# symboling : [ 3  1  2  0 -1 -2]
# ******************************************
# normalized-losses : ['?' '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
# ******************************************
# make : ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# ******************************************
# fuel-type : ['gas' 'diesel']
# ******************************************
# body-style : ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# ******************************************
# drive-wheels : ['rwd' 'fwd' '4wd']
# ...

# %%
# Replacing the question mark(?) with Nan values.

# We can use replace function only on string data not on numbers and Nan values.

data["normalized-losses"].replace("?",np.nan,inplace=True)
data["horsepower"].replace("?",np.nan,inplace=True)

# %%
col=["normalized-losses","horsepower"]

for i in col:
    print(i,":",data[i].unique())
    print("************************************")
# Out:
# normalized-losses : [nan '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
# ************************************
# horsepower : ['111' '154' '102' '115' '110' '140' '160' '101' '121' '182' '48' '70'
#  '68' '88' '145' '58' '76' '60' '86' '100' '78' '90' '176' '262' '135'
#  '84' '64' '120' '72' '123' '155' '184' '175' '116' '69' '55' '97' '152'
#  '200' '95' '142' '143' '207' '288' nan '73' '82' '94' '62' '56' '112'
#  '92' '161' '156' '52' '85' '114' '162' '134' '106']
# ************************************

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         203 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
data.isnull().sum() # This function will give number of Nan values in particular column.
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# body-style            0
# drive-wheels          0
# engine-location       0
# width                 0
# height                0
# engine-type           0
# engine-size           0
# horsepower            2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
# Changing the data type of normalized losses & horsepower.

# We are going to change data type of normalized losses & horsepower as it in object.
# Where there are Nan values in any column we cant directly change the column data type to interger.
# We have to change it by float value first.

data["normalized-losses"]=data["normalized-losses"].astype("float64")
data["horsepower"]=data["horsepower"].astype("float64")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         203 non-null    float64
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %%
data.describe()
# Out:
#         symboling  normalized-losses       width      height  engine-size  \
# count  205.000000         164.000000  205.000000  205.000000   205.000000
# mean     0.834146         122.000000   65.907805   53.724878   126.907317
# std      1.245307          35.442168    2.145204    2.443522    41.642693
# min     -2.000000          65.000000   60.300000   47.800000    61.000000
# 25%      0.000000          94.000000   64.100000   52.000000    97.000000
# 50%      1.000000         115.000000   65.500000   54.100000   120.000000
# 75%      2.000000         150.000000   66.900000   55.500000   141.000000
# max      3.000000         256.000000   72.300000   59.800000   326.000000
#
#        horsepower    city-mpg  highway-mpg         price
# count  203.000000  205.000000   205.000000    205.000000
# mean   104.256158   25.219512    30.751220  13227.478049
# std     39.714369    6.542142     6.886443   7902.651615
# min     48.000000   13.000000    16.000000   5118.000000
# ...

# %%
# As we have checked the mean value of normalized-losses and horsepower.
# We can replace Nan values with mean.

# Filna function is used to fill null values with any numbers.

data["normalized-losses"].fillna(122,inplace=True)
data["horsepower"].fillna(104,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    float64
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(4), int64(5), object(6)
# ...

# %%
data.describe()
# Out:
#         symboling  normalized-losses       width      height  engine-size  \
# count  205.000000         205.000000  205.000000  205.000000   205.000000
# mean     0.834146         122.000000   65.907805   53.724878   126.907317
# std      1.245307          31.681008    2.145204    2.443522    41.642693
# min     -2.000000          65.000000   60.300000   47.800000    61.000000
# 25%      0.000000         101.000000   64.100000   52.000000    97.000000
# 50%      1.000000         122.000000   65.500000   54.100000   120.000000
# 75%      2.000000         137.000000   66.900000   55.500000   141.000000
# max      3.000000         256.000000   72.300000   59.800000   326.000000
#
#        horsepower    city-mpg  highway-mpg         price
# count  205.000000  205.000000   205.000000    205.000000
# mean   104.253659   25.219512    30.751220  13227.478049
# std     39.519219    6.542142     6.886443   7902.651615
# min     48.000000   13.000000    16.000000   5118.000000
# ...

# %%
data
# Out:
#      symboling  normalized-losses         make fuel-type   body-style  \
# 0            3              122.0  alfa-romero       gas  convertible
# 1            3              122.0  alfa-romero       gas  convertible
# 2            1              122.0  alfa-romero       gas    hatchback
# 3            2              164.0         audi       gas        sedan
# 4            2              164.0         audi       gas        sedan
# ..         ...                ...          ...       ...          ...
# 200         -1               95.0        volvo       gas        sedan
# 201         -1               95.0        volvo       gas        sedan
# 202         -1               95.0        volvo       gas        sedan
# 203         -1               95.0        volvo    diesel        sedan
# 204         -1               95.0        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
# Handling outliers.

# An outliers is an observation that lies an abnormal distance from other values in a column.

plt.figure()
sns.boxplot(data["price"])
plt.show()

# %%
# We are going to find Q1,Q2,Q3 & IQR(Inter Quartile Range).

Q1=np.quantile(data["price"],0.25) # 25% of data
Q2=np.quantile(data["price"],0.50) # 50% of data
Q3=np.quantile(data["price"],0.75) # 75% of data

IQR=Q3-Q1

print("Q1:",Q1)
print("Q2:",Q2)
print("Q3:",Q3)
print("IQR:",IQR)
# Out:
# Q1: 7788.0
# Q2: 10345.0
# Q3: 16500.0
# IQR: 8712.0

# %%
# Upper whisker & Lower whisker.

UW=Q3+(1.5*IQR)
LW=Q1-(1.5*IQR)

print("LW:",LW)
print("UW:",UW)

# Any values less than Lower whisker and more than Upper whisker is considered as outliers.
# Out:
# LW: -5280.0
# UW: 29568.0

# %%
# Removing all outliers, we are going to plot makers with price.

plt.figure(figsize=(12,7))
sns.boxplot(data=data,x="price",y="make",palette="tab10")
plt.show()

# %%
# Removing all outliers with loop.

for maker in data["make"].unique(): # for loop will run on maker column of each maker as we given unique.
    price=data[data["make"]==maker]["price"] # All the maker price data will be store in price variable with index.
    Q1=np.quantile(price,0.25) # finding Q1.
    Q3=np.quantile(price,0.75) # finding Q3.
    IQR=Q3-Q1 # finding IQR for upper whsiker & Lower whisker
    UW=Q3+(1.5*IQR) # upper whsiker
    LW=Q1-(1.5*IQR) # lower whisker
    
    i=price[price>UW].index # All the data of price will be get stored in i with index number if price > UW
    if len(i)!=0: # i list length should not have 0 elements.It will store all row(index)number which is > UW
        data.drop(i,inplace=True)

# %%
plt.figure(figsize=(12,7))
sns.boxplot(data=data,x="price",y="make",palette="tab10")
plt.show()

# %%
data.shape
# Out:
# (194, 15)
